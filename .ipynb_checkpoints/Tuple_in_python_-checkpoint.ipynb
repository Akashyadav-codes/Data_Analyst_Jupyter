# %% [markdown]
# #### Tuple:
# 1. A tuple is a collection of similar to a python list. The primary difference is that we cannot modify a tuple once it is created.
# 2.A Tuple in python is an immutable ordered colletion of elements.
# 3. Tuple can hold elements of different datatypes.
# 4. Tuple denoted by parenthesis ().
# 5. Tuple store data on index d firt index by default index in tuple.
# 6. Tuple is a class of collection.

# %%
k=(23,4,45,34,34,34,"True","A",23.4,"Akash")
k
# Out:
# (23, 4, 45, 34, 34, 34, 'True', 'A', 23.4, 'Akash')

# %%
type(k)
# Out:
# tuple

# %%
a=(2,)
type(a)
# Out:
# tuple

# %%
k[0]
# Out:
# 23

# %%
k[3]="akki"  # It is immutable
k
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 k[3]="akki"
#       2 k
#
# TypeError: 'tuple' object does not support item assignment

# %%
k.index(34)
# Out:
# 3

# %%
k.count(34)
# Out:
# 3

# %%
# slicing 
print(k[::])
print(k[2:8])
print(k[-1])
# Out:
# (23, 4, 45, 34, 34, 34, 'True', 'A', 23.4, 'Akash')
# (45, 34, 34, 34, 'True', 'A')
# Akash

# %%
for i in k:
    if (type(i)==str):
        print(i)
# Out:
# True
# A
# Akash

# %%
for i in k:
    if (type(i)==float):
        print(i)
# Out:
# 23.4

# %%
t=1,2,3,4
type(t)
# Out:
# tuple

# %%
tup=(10,20,30)
a,b,c=tup
print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
# tuple to list convert
tup=(1,2,3,4)
lis=list(tup)
type(lis)
# Out:
# list
