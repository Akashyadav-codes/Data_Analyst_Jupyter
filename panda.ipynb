# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# CREATING A TABLE USING PANDA LIBRARY
import pandas as pd
data = {
    "Name": ["Akash", "Aditya","Anil","Chandan"],
    "Age":[21,22,21,23],
    "Course":["BCA","BCA","BCA","BCA"],
    "Language":["PYTHON","JAVA","JAVA","PYTHON"],
    "Marks":[90,85,43,67]
}
df= pd.DataFrame(data)


df.shape
df.head()
df.info()
df.tail()
df.columns
# df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      4 non-null      object
#  1   Age       4 non-null      int64
#  2   Course    4 non-null      object
#  3   Language  4 non-null      object
#  4   Marks     4 non-null      int64
# dtypes: int64(2), object(3)
# memory usage: 292.0+ bytes
# Index(['Name', 'Age', 'Course', 'Language', 'Marks'], dtype='object')

# %%
# SELECT THE SINGLE COLUMNS
df["Name"]
# Out:
# 0      Akash
# 1     Aditya
# 2       Anil
# 3    Chandan
# Name: Name, dtype: object

# %%
# SELECT THE MULTIPLE COLUMNS
df[["Name","Language"]]
# Out:
#       Name Language
# 0    Akash   PYTHON
# 1   Aditya     JAVA
# 2     Anil     JAVA
# 3  Chandan   PYTHON

# %%
# select by the row [ index,position ]
df.loc[0]
df.iloc[0]
# Out:
# Name         Akash
# Age             21
# Course         BCA
# Language    PYTHON
# Name: 0, dtype: object

# %%
# FILTER THE TABLES
df[df[ "Marks" ] >= 85]
df[(df["Marks"] > 20 ) & (df["Marks"] < 85)]
# Out:
#       Name  Age Course Language  Marks
# 2     Anil   21    BCA     JAVA     43
# 3  Chandan   23    BCA   PYTHON     67

# %%
data = {
    "Order id":[101,102,103,104],
    "Product":["Pen", " Pencil","Copy","Rubber"],
    "Quantity":[100,200,300,400],
    "Price":[10,5,40,2]
}
df=pd.DataFrame(data)
# df.info()
# df.head()
# df["Quantity"]
# df[["Product","Order id"]]
df.describe()
# Out:
#          Order id    Quantity      Price
# count    4.000000    4.000000   4.000000
# mean   102.500000  250.000000  14.250000
# std      1.290994  129.099445  17.480942
# min    101.000000  100.000000   2.000000
# 25%    101.750000  175.000000   4.250000
# 50%    102.500000  250.000000   7.500000
# 75%    103.250000  325.000000  17.500000
# max    104.000000  400.000000  40.000000

# %%
import mysql.connector
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="library_db",
    port=3306
)
cursor = conn.cursor()
cursor.execute("""
UPDATE books
SET issued_to = %s
WHERE id = %s
""",("rahul sharma",3))
conn.commit()
print(" issued_to updated")
# Out:
#  issued_to updated

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
print(mysql.connector.__version__)
# Out:
# 9.5.0

# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\brije\\anaconda3\\python.exe'

# %%
import pandas as pd
query = "SELECT * FROM books "
df=pd.read_sql(query,conn)
df.head()
# Out:
# C:\Users\brije\AppData\Local\Temp\ipykernel_972\769260257.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(query,conn)
#    id                 title         author          category  quantity  \
# 0   1      Java Programming  James Gosling       Programming         5
# 1   2      Database Systems      C.J. Date          Database         3
# 2   3      Operating System         Galvin  Computer Science         4
# 3   4  Python for Beginners     John Smith       Programming         6
# 4   5       Data Structures     Mark Allen  Computer Science         5
#
#    issued     issued_to due_date
# 0       0          None     None
# 1       0          None     None
# 2       0  rahul sharma     None
# 3       0          None     None
# 4       0          None     None

# %%
df["title"]
# Out:
# 0        Java Programming
# 1        Database Systems
# 2        Operating System
# 3    Python for Beginners
# 4         Data Structures
# 5                  python
# Name: title, dtype: object

# %%
import pandas as pd
query = "SELECT * FROM books "
df=pd.read_sql(query,conn)
df.head()
# Out:
# C:\Users\brije\AppData\Local\Temp\ipykernel_972\769260257.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(query,conn)
#    id                 title         author          category  quantity  \
# 0   1      Java Programming  James Gosling       Programming         5
# 1   2      Database Systems      C.J. Date          Database         3
# 2   3      Operating System         Galvin  Computer Science         4
# 3   4  Python for Beginners     John Smith       Programming         6
# 4   5       Data Structures     Mark Allen  Computer Science         5
#
#    issued     issued_to due_date
# 0       0          None     None
# 1       0          None     None
# 2       0  rahul sharma     None
# 3       0          None     None
# 4       0          None     None

# %%
cursor.execute("""
UPDATE books
SET issued = %s
WHERE id = %s
""",(1,0))
conn.commit()
print(" issued successfully")
# Out:
#  issued successfully

# %%
import pandas as pd
query = "select * from books"
df=pd.read_sql(query,conn)
df.head()
# Out:
# C:\Users\brije\AppData\Local\Temp\ipykernel_972\2452594034.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(query,conn)
#    id                 title         author          category  quantity  \
# 0   1      Java Programming  James Gosling       Programming         5
# 1   2      Database Systems      C.J. Date          Database         3
# 2   3      Operating System         Galvin  Computer Science         4
# 3   4  Python for Beginners     John Smith       Programming         6
# 4   5       Data Structures     Mark Allen  Computer Science         5
#
#    issued     issued_to due_date
# 0       0          None     None
# 1       0          None     None
# 2       0  rahul sharma     None
# 3       0          None     None
# 4       0          None     None

# %%
cursor.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 cursor.close()
#
# AttributeError: 'NoneType' object has no attribute 'close'

# %%
conn.close()

# %%
import mysql.connector
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password= "",
    database="library_db"
)
cursor=conn.connect()
print(" connect successfully")
# Out:
#  connect successfully

# %%
import pandas as pd
df= pd.read_sql(" select * from books",conn)
df
# Out:
# C:\Users\brije\AppData\Local\Temp\ipykernel_33800\537031853.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df= pd.read_sql(" select * from books",conn)
#    id                 title         author          category  quantity  \
# 0   1      Java Programming  James Gosling       Programming         5
# 1   2      Database Systems      C.J. Date          Database         3
# 2   3      Operating System         Galvin  Computer Science         4
# 3   4  Python for Beginners     John Smith       Programming         6
# 4   5       Data Structures     Mark Allen  Computer Science         5
# 5   6                python    akash yadav        programing         5
#
#    issued     issued_to due_date
# 0       0          None     None
# 1       0          None     None
# 2       0  rahul sharma     None
# ...

# %%
import pandas as pd
df= pd.read_sql(" select * from users",conn)
df
# Out:
# C:\Users\brije\AppData\Local\Temp\ipykernel_33800\1568559416.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df= pd.read_sql(" select * from users",conn)
#    id username  password     role
# 0   1    admin  admin123    admin
# 1   2    akash      1234  student
# 2   3  brijesh      1234  student
# 3   4    rahul      1234  student

# %%
# conn.close()
# conn.close()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 cursor.close()
#
# AttributeError: 'NoneType' object has no attribute 'close'

# %%
import mysql.connector
conn= mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="quiz_db"
)
cursor = conn.connect()
print(" connect successfully")
# Out:
#  connect successfully

# %%
import pandas as pd
df=pd.read_sql(" select * from users",conn)
df
# Out:
# C:\Users\brije\AppData\Local\Temp\ipykernel_33800\2134714846.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(" select * from users",conn)
#    id  username              email password_hash  is_admin          created_at
# 0   1     admin  admin@example.com      admin123         1 2025-11-15 01:12:41
# 1   2     akash  akash@example.com      akash123         0 2025-11-15 01:12:41
# 2   3  student1     s1@example.com          s123         0 2025-11-15 01:12:41
# 3   4  student2     s2@example.com          s234         0 2025-11-15 01:12:41

# %%
import pandas as pd
df = pd.read_sql(" select * from questions",conn)
df
# Out:
# C:\Users\brije\AppData\Local\Temp\ipykernel_33800\1945688062.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(" select * from questions",conn)
#    id   question_text option_a option_b option_c option_d correct_option  \
# 0   1           2+2=?        2        3        4        5              C
# 1   2           5*5=?       10       25       15       20              B
# 2   3  Water formula?      H2O      CO2       O2       H2              A
# 3   4       Sun is a?   Planet     Star     Moon    Comet              B
#
#    category_id
# 0            1
# 1            1
# 2            2
# 3            2

# %%
import pandas as pd 
df= pd.read_csv("customer.csv")
# df.isnull().sum()
# df.fidllna(0)
# df.dropna()
# df.rename(columns={"Customer Id" : " ID"}, inplace=True)
df["Full Name"] = df["First Name"] + " " + df["Last Name"]


df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.shape
# Out:
# (100, 12)

# %%
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
# Remove FullName column and store it
fullname = df.pop("Full Name")

# Insert it back at index 2
df.insert(2, "Full Name", fullname)

df
# Out:
#     Index      Customer Id        Full Name First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc    Sheryl Baxter     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10   Preston Lozano    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy Berry        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda Olsen      Linda     Olsen
# 4       5  053d585Ab6b3159    Joanna Bender     Joanna    Bender
# ..    ...              ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl Greer       Karl     Greer
# 96     97  CeD220bdAaCfaDf    Lynn Atkinson       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db      Fred Guerra       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A    Yvonne Farmer     Yvonne    Farmer
# 99    100  2354a0E336A91A1  Clarence Haynes   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# ...

# %%
import pandas as pd
df=pd.read_csv("ipl.csv")

df
# Out:
# C:\Users\brije\AppData\Local\Temp\ipykernel_3648\1576376294.py:2: DtypeWarning: Columns (28,29,30,31,43,46,47,48,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("ipl.csv")
#         Unnamed: 0  match_id        date match_type             event_name  \
# 0           131970    335982  2008-04-18        T20  Indian Premier League
# 1           131971    335982  2008-04-18        T20  Indian Premier League
# 2           131972    335982  2008-04-18        T20  Indian Premier League
# 3           131973    335982  2008-04-18        T20  Indian Premier League
# 4           131974    335982  2008-04-18        T20  Indian Premier League
# ...            ...       ...         ...        ...                    ...
# 278200      277951   1473511  2025-06-03        T20  Indian Premier League
# 278201      277952   1473511  2025-06-03        T20  Indian Premier League
# 278202      277953   1473511  2025-06-03        T20  Indian Premier League
# ...

# %%
# JUST FOR INFO

# df.head()
df.info



# IF WE WANT TO RENAME COLUMNS MORE THAN ONE
# df.rename(columns={"match_id": "Match_Id",
#                   "match_type":"Match_Type",
#                    "event_name":"Event_Name"          
#                   }, inplace=True)
# df


# # IF WE WANT TO CHANGE FIRST LETTER OF EVERY COLUMMNS IS CAPITAL
# df.columns=df.columns.str.title()
# df
# Out:
# <bound method DataFrame.info of         Unnamed: 0  Match_Id        Date Match_Type             Event_Name  \
# 0           131970    335982  2008-04-18        T20  Indian Premier League
# 1           131971    335982  2008-04-18        T20  Indian Premier League
# 2           131972    335982  2008-04-18        T20  Indian Premier League
# 3           131973    335982  2008-04-18        T20  Indian Premier League
# 4           131974    335982  2008-04-18        T20  Indian Premier League
# ...            ...       ...         ...        ...                    ...
# 278200      277951   1473511  2025-06-03        T20  Indian Premier League
# 278201      277952   1473511  2025-06-03        T20  Indian Premier League
# 278202      277953   1473511  2025-06-03        T20  Indian Premier League
# 278203      277954   1473511  2025-06-03        T20  Indian Premier League
# 278204      277955   1473511  2025-06-03        T20  Indian Premier League
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# Match_Id                 0
# Date                     0
# Match_Type               0
# Event_Name               0
#                      ...
# Batter_Balls             0
# Bowler_Wicket            0
# Batting_Partners         0
# Next_Batter         264884
# Striker_Out              0
# Length: 64, dtype: int64

# %%
df.describe()
# Out:
#           Unnamed: 0      Match_Id        Innings           Over  \
# count  278205.000000  2.782050e+05  278205.000000  278205.000000
# mean   139102.000000  9.422687e+05       1.482914       9.193839
# std     80311.010157  3.817198e+05       0.502571       5.681511
# min         0.000000  3.359820e+05       1.000000       0.000000
# 25%     69551.000000  5.483530e+05       1.000000       4.000000
# 50%    139102.000000  1.082601e+06       1.000000       9.000000
# 75%    208653.000000  1.304049e+06       2.000000      14.000000
# max    278204.000000  1.485779e+06       6.000000      19.000000
#
#                 Ball        Ball_No        Bat_Pos    Runs_Batter  \
# count  278205.000000  278205.000000  278205.000000  278205.000000
# mean        3.488855       9.542725       3.612555       1.277378
# std         1.708263       5.682938       2.168978       1.651107
# min         1.000000       0.100000       1.000000       0.000000
# ...

# %%
# df.columns
df.drop("unnamed
# Out:
# Index(['Unnamed: 0', 'Match_Id', 'Date', 'Match_Type', 'Event_Name', 'Innings',
#        'Batting_Team', 'Bowling_Team', 'Over', 'Ball', 'Ball_No', 'Batter',
#        'Bat_Pos', 'Runs_Batter', 'Balls_Faced', 'Bowler', 'Valid_Ball',
#        'Runs_Extras', 'Runs_Total', 'Runs_Bowler', 'Runs_Not_Boundary',
#        'Extra_Type', 'Non_Striker', 'Non_Striker_Pos', 'Wicket_Kind',
#        'Player_Out', 'Fielders', 'Runs_Target', 'Review_Batter',
#        'Team_Reviewed', 'Review_Decision', 'Umpire', 'Umpires_Call',
#        'Player_Of_Match', 'Match_Won_By', 'Win_Outcome', 'Toss_Winner',
#        'Toss_Decision', 'Venue', 'City', 'Day', 'Month', 'Year', 'Season',
#        'Gender', 'Team_Type', 'Superover_Winner', 'Result_Type', 'Method',
#        'Balls_Per_Over', 'Overs', 'Event_Match_No', 'Stage', 'Match_Number',
#        'Team_Runs', 'Team_Balls', 'Team_Wicket', 'New_Batter', 'Batter_Runs',
#        'Batter_Balls', 'Bowler_Wicket', 'Batting_Partners', 'Next_Batter',
# ...

# %%
# PERFORMIMNG THE CALCULATION IN ROWS AND COLOMNS WE CAN USE THE THREE SPECIAL FUNCTION
# map() : it is usedd for performing the row calculation
# apply() : It is used for performing the columns calculation
# applymap() : It is used for overall calculation mean that apply allover the entire data of row and columns

# %%
import pandas as pd
df=pd.read_excel("Raw Data .xlsx")
df
# Out:
#     Id      Name  Lastname  Salary Department  Mobile no.
# 0    1     Anshu    Rajput   90000      Sales  8595787610
# 1    2    Manish     Kumar   62000  Marketing  8595787611
# 2    3     Aadil      Khan   70000    Finance  8595787612
# 3    4   Chandan    Thakur   80000         IT  8595787613
# 4    5      Aman     Anand   20000      Sales  8595787614
# 5    6     Badal     Singh   65000  Marketing  8595787615
# 6    7      Anil     Yadav   55000    Finance  8595787616
# 7    8     Akash     Verma   75000         IT  8595787617
# 8    9      Yash  Kushwaha   25000      Sales  8595787618
# 9   10  Abhishek     Yadav   95000  Marketing  8595787619
# 10  11   Aaditya     Yadav   10000    Finance  8595787620
# 11  12     Daksh   Chauhan   66000         IT  8595787621
# 12  13     Ayush     Singh   30000      Sales  8595787622
# 13  14      Arun     Singh   89000  Marketing  8595787623
# 14  15    Ashish     Rawat   90000    Finance  8595787624
# ...

# %%
# JOIN IN PANDAS
# left join :It can show the full left side data and compare with right side data
# right join : It can show the full right side data  and compare with left side data.
# inner join : It can shiw the common data in both left and  right side data.
# outer join : It can show the overall comparison  of left and right both side data at a time.

# %%
one=pd.DataFrame( {
 "id":[1,2,3,4],
    "Name": ["Akash", "Aditya","Anil","Chandan"],
}) 
one
# Out:
#    id     Name
# 0   1    Akash
# 1   2   Aditya
# 2   3     Anil
# 3   4  Chandan

# %%
two= pd.DataFrame( {
    "id": [6,7,3,4],
   
    "Sub_id":["sub1","sub2","sub3","sub4"]
})
two
# Out:
#    id Sub_id
# 0   6   sub1
# 1   7   sub2
# 2   3   sub3
# 3   4   sub4

# %%
import pandas as pd

df1 = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['Akash', 'Ravi', 'Neha', 'Pooja']
})

df2 = pd.DataFrame({
    'id': [3, 4, 5],
    'marks': [85, 90, 88]
})
pd.merge(df1, df2, on='id', how='inner')
# Out:
#    id   name  marks
# 0   3   Neha     85
# 1   4  Pooja     90

# %%
======================= PRACTICE ON CSV FILE i.e CRIME DATASET INDIA ===============================================

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\brije\OneDrive\Documents\Desktop\crime_dataset_india.csv")
df
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0                  1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 1                  2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2                  3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3                  4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4                  5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
# ...              ...               ...                ...                ...
# 40155          40156  01-08-2024 16:00   07-31-2024 03:00   31-07-2024 05:05
# 40156          40157  31-07-2024 14:00   07-31-2024 04:00   31-07-2024 04:14
# 40157          40158  02-08-2024 03:00   07-31-2024 05:00   31-07-2024 21:33
# 40158          40159  01-08-2024 19:00   07-31-2024 06:00   31-07-2024 11:05
# 40159          40160  31-07-2024 17:00   07-31-2024 07:00   31-07-2024 17:19
#
# ...

# %%
df.shape
# Out:
# (40160, 14)

# %%
df.columns
# Out:
# Index(['Report Number', 'Date Reported', 'Date of Occurrence',
#        'Time of Occurrence', 'City', 'Crime Code', 'Crime Description',
#        'Victim Age', 'Victim Gender', 'Weapon Used', 'Crime Domain',
#        'Police Deployed', 'Case Closed', 'Date Case Closed'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40160 entries, 0 to 40159
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Report Number       40160 non-null  int64
#  1   Date Reported       40160 non-null  object
#  2   Date of Occurrence  40160 non-null  object
#  3   Time of Occurrence  40160 non-null  object
#  4   City                40160 non-null  object
#  5   Crime Code          40160 non-null  int64
#  6   Crime Description   40160 non-null  object
#  7   Victim Age          40160 non-null  int64
#  8   Victim Gender       40160 non-null  object
#  9   Weapon Used         34370 non-null  object
#  10  Crime Domain        40160 non-null  object
#  11  Police Deployed     40160 non-null  int64
#  12  Case Closed         40160 non-null  object
#  13  Date Case Closed    20062 non-null  object
# dtypes: int64(4), object(10)
# memory usage: 4.3+ MB

# %%
df.head(10)
# Out:
#    Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0              1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 1              2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2              3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3              4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4              5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
# 5              6  02-01-2020 03:00   01-01-2020 05:00   01-01-2020 17:09
# 6              7  01-01-2020 16:00   01-01-2020 06:00   01-01-2020 14:08
# 7              8  02-01-2020 10:00   01-01-2020 07:00   02-01-2020 06:33
# 8              9  04-01-2020 03:00   01-01-2020 08:00   02-01-2020 06:34
# 9             10  03-01-2020 07:00   01-01-2020 09:00   01-01-2020 17:50
#
#         City  Crime Code    Crime Description  Victim Age Victim Gender  \
# 0  Ahmedabad         576       IDENTITY THEFT          16             M
# ...

# %%
df['Victim Age'].describe()
# Out:
# count    40160.00000
# mean        44.49126
# std         20.22555
# min         10.00000
# 25%         27.00000
# 50%         44.00000
# 75%         62.00000
# max         79.00000
# Name: Victim Age, dtype: float64

# %%
# df[df['City']=='Delhi']
df[df['City']== 'Mumbai']
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 8                  9  04-01-2020 03:00   01-01-2020 08:00   02-01-2020 06:34
# 13                14  02-01-2020 22:00   01-01-2020 13:00   01-01-2020 17:46
# 21                22  03-01-2020 12:00   01-01-2020 21:00   02-01-2020 10:11
# 39                40  03-01-2020 02:00   01-02-2020 15:00   03-01-2020 14:05
# 43                44  04-01-2020 07:00   01-02-2020 19:00   03-01-2020 08:34
# ...              ...               ...                ...                ...
# 40145          40146  31-07-2024 22:00   07-30-2024 17:00   31-07-2024 00:01
# 40149          40150  31-07-2024 19:00   07-30-2024 21:00   31-07-2024 15:43
# 40150          40151  01-08-2024 23:00   07-30-2024 22:00   31-07-2024 19:41
# 40151          40152  01-08-2024 00:00   07-30-2024 23:00   30-07-2024 23:10
# 40156          40157  31-07-2024 14:00   07-31-2024 04:00   31-07-2024 04:14
#
# ...

# %%
# df[df["Victim Gender"]== "M"]
# df[df["Victim Gender"]== "M"].count()
df[df['Victim Gender']== 'F']
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 2                  3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3                  4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4                  5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
# 6                  7  01-01-2020 16:00   01-01-2020 06:00   01-01-2020 14:08
# 12                13  01-01-2020 16:00   01-01-2020 12:00   01-01-2020 23:14
# ...              ...               ...                ...                ...
# 40153          40154  31-07-2024 17:00   07-31-2024 01:00   31-07-2024 21:42
# 40154          40155  01-08-2024 11:00   07-31-2024 02:00   31-07-2024 12:59
# 40155          40156  01-08-2024 16:00   07-31-2024 03:00   31-07-2024 05:05
# 40156          40157  31-07-2024 14:00   07-31-2024 04:00   31-07-2024 04:14
# 40159          40160  31-07-2024 17:00   07-31-2024 07:00   31-07-2024 17:19
#
# ...

# %%
# df[df['Victim Age']<=30]
df[df["Victim Age"]>30]
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 1                  2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2                  3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3                  4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 6                  7  01-01-2020 16:00   01-01-2020 06:00   01-01-2020 14:08
# 7                  8  02-01-2020 10:00   01-01-2020 07:00   02-01-2020 06:33
# ...              ...               ...                ...                ...
# 40154          40155  01-08-2024 11:00   07-31-2024 02:00   31-07-2024 12:59
# 40155          40156  01-08-2024 16:00   07-31-2024 03:00   31-07-2024 05:05
# 40156          40157  31-07-2024 14:00   07-31-2024 04:00   31-07-2024 04:14
# 40157          40158  02-08-2024 03:00   07-31-2024 05:00   31-07-2024 21:33
# 40159          40160  31-07-2024 17:00   07-31-2024 07:00   31-07-2024 17:19
#
# ...

# %%
df[(df['Victim Gender'] == 'Male') & (df['Case Closed'] == 'Yes')]
# Out:
# Empty DataFrame
# Columns: [Report Number, Date Reported, Date of Occurrence, Time of Occurrence, City, Crime Code, Crime Description, Victim Age, Victim Gender, Weapon Used, Crime Domain, Police Deployed, Case Closed, Date Case Closed]
# Index: []

# %%
# df[df["Weapon Used"]=="Knife"]
df[df["Weapon Used"]=="Knife"].count()
# Out:
# Report Number         5835
# Date Reported         5835
# Date of Occurrence    5835
# Time of Occurrence    5835
# City                  5835
# Crime Code            5835
# Crime Description     5835
# Victim Age            5835
# Victim Gender         5835
# Weapon Used           5835
# Crime Domain          5835
# Police Deployed       5835
# Case Closed           5835
# Date Case Closed      2906
# dtype: int64

# %%
df.sort_values(by="Victim Age",ascending=True).head(20)
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 28920          28921  22-04-2023 12:00   04-20-2023 00:00   20-04-2023 14:30
# 39453          39454  02-07-2024 06:00   07-01-2024 21:00   01-07-2024 21:05
# 34781          34782  21-12-2023 07:00   12-20-2023 05:00   20-12-2023 07:44
# 38146          38147  11-05-2024 08:00   05-08-2024 10:00   08-05-2024 23:44
# 15570          15571  12-10-2021 00:00   10-10-2021 18:00   11-10-2021 02:08
# 9144            9145  16-01-2021 03:00   01-16-2021 00:00   16-01-2021 22:29
# 20099          20100  19-04-2022 00:00   04-17-2022 11:00   17-04-2022 11:34
# 33346          33347  22-10-2023 05:00   10-21-2023 10:00   21-10-2023 22:25
# 14132          14133  11-08-2021 23:00   08-11-2021 20:00   12-08-2021 03:48
# 31370          31371  01-08-2023 07:00   07-31-2023 02:00   31-07-2023 12:32
# 38992          38993  14-06-2024 09:00   06-12-2024 16:00   13-06-2024 08:24
# ...

# %%
p=df["City"].value_counts()
pd.DataFrame(p)
# Out:
#                count
# City
# Delhi           5400
# Mumbai          4415
# Bangalore       3588
# Hyderabad       2881
# Kolkata         2518
# Chennai         2493
# Pune            2212
# Ahmedabad       1817
# Jaipur          1479
# Lucknow         1456
# Kanpur          1112
# Surat           1111
# Nagpur          1053
# Agra             764
# Ludhiana         761
# Visakhapatnam    728
# Thane            706
# Ghaziabad        704
# Indore           699
# Patna            695
# Bhopal           690
# Meerut           395
# Srinagar         371
# Nashik           366
# Vasai            362
# Varanasi         355
# Kalyan           355
# Faridabad        354
# Rajkot           320

# %%
# df["Crime Description"].value_counts().head(1)
# df['City'].value_counts().head(1)
df["Crime Description"].value_counts().head(1)
# Out:
# Crime Description
# BURGLARY    1980
# Name: count, dtype: int64

# %%
df["Crime Domain"].value_counts()
# Out:
# Crime Domain
# Other Crime         22948
# Violent Crime       11472
# Fire Accident        3825
# Traffic Fatality     1915
# Name: count, dtype: int64

# %%
q=df[['City','Victim Age','Victim Gender']].value_counts()
q
# Out:
# City       Victim Age  Victim Gender
# Delhi      35          F                62
#            18          F                59
#            30          F                58
#            73          F                57
#            48          F                55
#                                         ..
# Rajkot     21          M                 1
#            19          F                 1
#            18          F                 1
#            17          M                 1
# Ghaziabad  33          X                 1
# Name: count, Length: 5371, dtype: int64

# %%
df["Weapon Used"].value_counts().head(5)
# Out:
# Weapon Used
# Knife           5835
# Explosives      5751
# Blunt Object    5737
# Poison          5728
# Other           5676
# Name: count, dtype: int64

# %%
df.groupby("City").size()
# Out:
# City
# Agra              764
# Ahmedabad        1817
# Bangalore        3588
# Bhopal            690
# Chennai          2493
# Delhi            5400
# Faridabad         354
# Ghaziabad         704
# Hyderabad        2881
# Indore            699
# Jaipur           1479
# Kalyan            355
# Kanpur           1112
# Kolkata          2518
# Lucknow          1456
# Ludhiana          761
# Meerut            395
# Mumbai           4415
# Nagpur           1053
# Nashik            366
# Patna             695
# Pune             2212
# Rajkot            320
# Srinagar          371
# Surat            1111
# Thane             706
# Varanasi          355
# Vasai             362
# Visakhapatnam     728
# dtype: int64

# %%
df.groupby("Victim Age").size()
# Out:
# Victim Age
# 10    571
# 11    606
# 12    534
# 13    574
# 14    542
#      ...
# 75    565
# 76    607
# 77    555
# 78    596
# 79    597
# Length: 70, dtype: int64

# %%
df.groupby("Victim Gender").size()
# Out:
# Victim Gender
# F    22423
# M    13405
# X     4332
# dtype: int64

# %%
df.groupby("City")["Victim Age"].mean()
# Out:
# City
# Agra             43.691099
# Ahmedabad        44.319207
# Bangalore        44.658584
# Bhopal           44.198551
# Chennai          44.061372
# Delhi            44.225370
# Faridabad        45.867232
# Ghaziabad        44.654830
# Hyderabad        44.190212
# Indore           43.811159
# Jaipur           44.883029
# Kalyan           45.214085
# Kanpur           44.130396
# Kolkata          44.720016
# Lucknow          44.794643
# Ludhiana         44.839685
# Meerut           44.987342
# Mumbai           44.326614
# Nagpur           44.523267
# Nashik           45.918033
# Patna            44.752518
# Pune             44.968807
# Rajkot           43.693750
# Srinagar         43.382749
# Surat            44.806481
# Thane            45.773371
# Varanasi         44.526761
# Vasai            45.433702
# Visakhapatnam    44.285714
# Name: Victim Age, dtype: float64

# %%
q=df.groupby("Crime Description")["Police Deployed"].max()
pd.DataFrame(q)
# Out:
#                      Police Deployed
# Crime Description
# ARSON                             19
# ASSAULT                           19
# BURGLARY                          19
# COUNTERFEITING                    19
# CYBERCRIME                        19
# DOMESTIC VIOLENCE                 19
# DRUG OFFENSE                      19
# EXTORTION                         19
# FIREARM OFFENSE                   19
# FRAUD                             19
# HOMICIDE                          19
# IDENTITY THEFT                    19
# ILLEGAL POSSESSION                19
# KIDNAPPING                        19
# PUBLIC INTOXICATION               19
# ROBBERY                           19
# SEXUAL ASSAULT                    19
# SHOPLIFTING                       19
# TRAFFIC VIOLATION                 19
# VANDALISM                         19
# VEHICLE - STOLEN                  19

# %%
# THERE IS TWO WAY TO CALCULATE COUNT
# df.groupby("Case Closed").size()
df["Case Closed"].value_counts()
# Out:
# Case Closed
# No     20098
# Yes    20062
# Name: count, dtype: int64

# %%
def age_group(age):
    if age < 18:
        return "Minor"
    elif age <= 40:
        return "Adult"
    else:
        return "Senior"
df["Age Group"] = df["Victim Age"].apply(age_group)
df[["Victim Age","Age Group"]].head()
# Out:
#    Victim Age Age Group
# 0          16     Minor
# 1          37     Adult
# 2          48    Senior
# 3          49    Senior
# 4          30     Adult

# %%
df
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0                  1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 1                  2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2                  3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3                  4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4                  5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
# ...              ...               ...                ...                ...
# 40155          40156  01-08-2024 16:00   07-31-2024 03:00   31-07-2024 05:05
# 40156          40157  31-07-2024 14:00   07-31-2024 04:00   31-07-2024 04:14
# 40157          40158  02-08-2024 03:00   07-31-2024 05:00   31-07-2024 21:33
# 40158          40159  01-08-2024 19:00   07-31-2024 06:00   31-07-2024 11:05
# 40159          40160  31-07-2024 17:00   07-31-2024 07:00   31-07-2024 17:19
#
# ...

# %%
df["Case Status"]= df["Case Closed"].map({"Yes":1,"No":0})
df[["Case Closed","Case Status"]].head()
# Out:
#   Case Closed  Case Status
# 0          No            0
# 1          No            0
# 2          No            0
# 3         Yes            1
# 4         Yes            1

# %%
df
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0                  1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 1                  2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2                  3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3                  4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4                  5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
# ...              ...               ...                ...                ...
# 40155          40156  01-08-2024 16:00   07-31-2024 03:00   31-07-2024 05:05
# 40156          40157  31-07-2024 14:00   07-31-2024 04:00   31-07-2024 04:14
# 40157          40158  02-08-2024 03:00   07-31-2024 05:00   31-07-2024 21:33
# 40158          40159  01-08-2024 19:00   07-31-2024 06:00   31-07-2024 11:05
# 40159          40160  31-07-2024 17:00   07-31-2024 07:00   31-07-2024 17:19
#
# ...

# %%
df.isnull().sum()
# Out:
# Report Number             0
# Date Reported             0
# Date of Occurrence        0
# Time of Occurrence        0
# City                      0
# Crime Code                0
# Crime Description         0
# Victim Age                0
# Victim Gender             0
# Weapon Used            5790
# Crime Domain              0
# Police Deployed           0
# Case Closed               0
# Date Case Closed      20098
# Age Group                 0
# Case Status               0
# Case status               0
# dtype: int64

# %%
df['Victim Age'].fillna(df['Victim Age'].mean(), inplace=True)
# Out:
# C:\Users\brije\AppData\Local\Temp\ipykernel_30668\2809840026.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Victim Age'].fillna(df['Victim Age'].mean(), inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df["City"].value_counts().idxmax()
# Out:
# 'Delhi'

# %%
df[df["Victim Gender"]=="F"]["Crime Description"].value_counts().head(1)
# Out:
# Crime Description
# VANDALISM    1144
# Name: count, dtype: int64

# %%
(df["Case Closed"]=="Yes").mean()*100
# Out:
# np.float64(49.95517928286853)

# %%
df["Police Deployed"].mean()
# Out:
# np.float64(10.00625)

# %%
del df["Case status"]

# %%
df
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0                  1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 1                  2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2                  3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3                  4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4                  5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
# ...              ...               ...                ...                ...
# 40155          40156  01-08-2024 16:00   07-31-2024 03:00   31-07-2024 05:05
# 40156          40157  31-07-2024 14:00   07-31-2024 04:00   31-07-2024 04:14
# 40157          40158  02-08-2024 03:00   07-31-2024 05:00   31-07-2024 21:33
# 40158          40159  01-08-2024 19:00   07-31-2024 06:00   31-07-2024 11:05
# 40159          40160  31-07-2024 17:00   07-31-2024 07:00   31-07-2024 17:19
#
# ...

# %%
Enqry=df.groupby("City")["Victim Gender"].count()
print(Enqry)
# Out:
# City
# Agra              764
# Ahmedabad        1817
# Bangalore        3588
# Bhopal            690
# Chennai          2493
# Delhi            5400
# Faridabad         354
# Ghaziabad         704
# Hyderabad        2881
# Indore            699
# Jaipur           1479
# Kalyan            355
# Kanpur           1112
# Kolkata          2518
# Lucknow          1456
# Ludhiana          761
# Meerut            395
# Mumbai           4415
# Nagpur           1053
# Nashik            366
# Patna             695
# Pune             2212
# Rajkot            320
# Srinagar          371
# Surat            1111
# Thane             706
# Varanasi          355
# Vasai             362
# Visakhapatnam     728
# Name: Victim Gender, dtype: int64

# %%
# show the bar Graph city through victim gender
import matplotlib.pyplot as plt
Enqry.plot(kind="bar")
plt.title(" Showing Graph City through Victim gender ")
plt.xlabel("City")
plt.ylabel("Counts of Victim Gender")
plt.show()

# %%
plt.figure(figsize=(11,11))
Enqry.plot(kind="pie")
plt.title(" Showing Graph City through Victim Gender (counts) ")
# plt.xlabel("City")
# plt.ylabel("Counts of Victim Gender")
plt.show()

# %%
# ==================== Practice ============
df=pd.read_csv(r"C:\Users\brije\Downloads\people-100.csv")
df
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1        bethany14@example.com       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %%
df.head()
df.isnull().sum()
df.describe
# Out:
# <bound method NDFrame.describe of     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1        bethany14@example.com       214.112.6044x4913    1910-03-24
# ...

# %%
df["Job Title"].value_counts()
# Out:
# Job Title
# Biochemist, clinical                                           3
# Scientist, clinical (histocompatibility and immunogenetics)    2
# Accountant, chartered management                               2
# Outdoor activities/education manager                           2
# Jewellery designer                                             2
#                                                               ..
# Art gallery manager                                            1
# Recycling officer                                              1
# Counsellor                                                     1
# Conservation officer, nature                                   1
# IT sales professional                                          1
# Name: count, Length: 91, dtype: int64

# %%
df.columns
# Out:
# Index(['Index', 'User Id', 'First Name', 'Last Name', 'Sex', 'Email', 'Phone',
#        'Date of birth', 'Job Title'],
#       dtype='object')

# %%
df["Full Name"]=df["First Name"]+" "+df["Last Name"]
df
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1        bethany14@example.com       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %%
df["Sex"].value_counts()
# Out:
# Sex
# Female    53
# Male      47
# Name: count, dtype: int64

# %%
df.drop_duplicates()
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1        bethany14@example.com       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %%
df.sort_values(by="Sex",inplace=True)
# Out:
#     Index          User Id First Name   Last Name     Sex  \
# 33     34  6Dec5b5542F8ed8    Brandon     Schmidt  Female
# 30     31  5d2feAfbdCAA6B5     Isaiah     Camacho  Female
# 67     68  3faB1CBfEFBDdD4   Brittney       Rubio  Female
# 90     91  F0aeC9c2759F3C6     Alison       Nixon  Female
# 89     90  9425E2F38C408ef      Kathy       Haney  Female
# ..    ...              ...        ...         ...     ...
# 82     83  AedDfaE8Cf49F07   Reginald  Stephenson    Male
# 49     50  E47FB71DD9ACCd9     Joshua     Sweeney    Male
# 2       3  DbeAb8CcdfeFC2c   Kristine      Travis    Male
# 36     37  aa614aAE4B7Cf0C    Leonard       Hurst    Male
# 99    100  b8D0aD3490FC7e1     Mariah     Bernard    Male
#
#                      Email                Phone Date of birth  \
# 33     mconley@example.net  +1-386-673-1465x006    1931-05-12
# 30    jimblake@example.org     001-536-544-3367    1966-04-07
# 67     corey92@example.com         593.976.2528    1959-12-24
# ...

# %%
df.columns=df.columns.str.title().str.replace(" ","_").str.strip()
df.columns
df
# Out:
#     Index          User_Id First_Name   Last_Name     Sex  \
# 33     34  6Dec5b5542F8ed8    Brandon     Schmidt  Female
# 30     31  5d2feAfbdCAA6B5     Isaiah     Camacho  Female
# 67     68  3faB1CBfEFBDdD4   Brittney       Rubio  Female
# 90     91  F0aeC9c2759F3C6     Alison       Nixon  Female
# 89     90  9425E2F38C408ef      Kathy       Haney  Female
# ..    ...              ...        ...         ...     ...
# 82     83  AedDfaE8Cf49F07   Reginald  Stephenson    Male
# 49     50  E47FB71DD9ACCd9     Joshua     Sweeney    Male
# 2       3  DbeAb8CcdfeFC2c   Kristine      Travis    Male
# 36     37  aa614aAE4B7Cf0C    Leonard       Hurst    Male
# 99    100  b8D0aD3490FC7e1     Mariah     Bernard    Male
#
#                      Email                Phone Date_Of_Birth  \
# 33     mconley@example.net  +1-386-673-1465x006    1931-05-12
# 30    jimblake@example.org     001-536-544-3367    1966-04-07
# 67     corey92@example.com         593.976.2528    1959-12-24
# ...

# %%
enqry=df.groupby("First_Name")["Sex"].sum()
print(enqry)
# Out:
# First_Name
# Alfred      Female
# Alison      Female
# Alvin         Male
# Andrew        Male
# Becky         Male
#              ...
# Veronica    Female
# Wesley        Male
# Willie      Female
# Xavier        Male
# Yesenia       Male
# Name: Sex, Length: 94, dtype: object

# %%
# handling missing value in datasets
# example.
import numpy as np
s=np.array([4,5,6,np.nan,6,7,np.nan])
s
# Out:
# array([ 4.,  5.,  6., nan,  6.,  7., nan])

# %%
np.sum(s)
# Out:
# np.float64(nan)

# %%
import pandas as pd
df=pd.read_excel(r"C:\Users\brije\Downloads\DATA12.xlsx")
df
# Out:
#     ID             Name            Industry  Inception       Revenue  \
# 0  1.0          Lamtone         IT Services     2009.0  $11,757,018
# 1  2.0        Stripfind  Financial Services     2010.0  $12,329,371
# 2  3.0  Canecorporation              Health     2012.0  $10,597,009
# 3  4.0              NaN         IT Services     2013.0           NaN
# 4  5.0              NaN                 NaN        NaN           NaN
# 5  6.0         Techline              Health     2006.0           NaN
# 6  7.0          Cityace                 NaN     2010.0   $9,254,614
# 7  8.0   Kayelectronics                 NaN     2009.0   $9,451,943
# 8  9.0          Ganzlax         IT Services     2011.0  $14,001,180
# 9  NaN              NaN                 NaN        NaN           NaN
#
#             Expenses      Profit  Growth  Salary
# 0  6,482,465 Dollars   5274553.0    0.30     NaN
# 1    916,455 Dollars  11412916.0     NaN     NaN
# 2                NaN   3005820.0     NaN     NaN
# ...

# %%
df.shape
# Out:
# (10, 9)

# %%
#check null value in each columns
df.isnull().sum()
# Out:
# ID            1
# Name          3
# Industry      4
# Inception     2
# Revenue       4
# Expenses      4
# Profit        1
# Growth        5
# Salary       10
# dtype: int64

# %%
# Checking nan in row-wise
df.isnull().sum(axis=1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    6
# 5    2
# 6    3
# 7    2
# 8    2
# 9    9
# dtype: int64

# %%
# Remove nan(not a numerical value) coloumns
df.drop(["Salary"],axis=1,inplace=True)

# %%
df
# Out:
#     ID             Name            Industry  Inception       Revenue  \
# 0  1.0          Lamtone         IT Services     2009.0  $11,757,018
# 1  2.0        Stripfind  Financial Services     2010.0  $12,329,371
# 2  3.0  Canecorporation              Health     2012.0  $10,597,009
# 3  4.0              NaN         IT Services     2013.0           NaN
# 4  5.0              NaN                 NaN        NaN           NaN
# 5  6.0         Techline              Health     2006.0           NaN
# 6  7.0          Cityace                 NaN     2010.0   $9,254,614
# 7  8.0   Kayelectronics                 NaN     2009.0   $9,451,943
# 8  9.0          Ganzlax         IT Services     2011.0  $14,001,180
# 9  NaN              NaN                 NaN        NaN           NaN
#
#             Expenses      Profit  Growth
# 0  6,482,465 Dollars   5274553.0    0.30
# 1    916,455 Dollars  11412916.0     NaN
# 2                NaN   3005820.0     NaN
# 3  7,429,377 Dollars   6597557.0     NaN
# ...

# %%
# Remove nan row
df.dropna(how="all",inplace=True)
df
# Out:
#     ID             Name            Industry  Inception       Revenue  \
# 0  1.0          Lamtone         IT Services     2009.0  $11,757,018
# 1  2.0        Stripfind  Financial Services     2010.0  $12,329,371
# 2  3.0  Canecorporation              Health     2012.0  $10,597,009
# 3  4.0              NaN         IT Services     2013.0           NaN
# 4  5.0              NaN                 NaN        NaN           NaN
# 5  6.0         Techline              Health     2006.0           NaN
# 6  7.0          Cityace                 NaN     2010.0   $9,254,614
# 7  8.0   Kayelectronics                 NaN     2009.0   $9,451,943
# 8  9.0          Ganzlax         IT Services     2011.0  $14,001,180
#
#             Expenses      Profit  Growth
# 0  6,482,465 Dollars   5274553.0    0.30
# 1    916,455 Dollars  11412916.0     NaN
# 2                NaN   3005820.0     NaN
# 3  7,429,377 Dollars   6597557.0     NaN
# 4  7,435,363 Dollars   3138627.0     NaN
# ...

# %%
# Checking % of nan in every columns
df.isnull().sum()/len(df)
# Out:
# ID           0.000000
# Name         0.222222
# Industry     0.333333
# Inception    0.111111
# Revenue      0.333333
# Expenses     0.333333
# Profit       0.000000
# Growth       0.444444
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 0 to 8
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         9 non-null      float64
#  1   Name       7 non-null      object
#  2   Industry   6 non-null      object
#  3   Inception  8 non-null      float64
#  4   Revenue    6 non-null      object
#  5   Expenses   6 non-null      object
#  6   Profit     9 non-null      float64
#  7   Growth     5 non-null      float64
# dtypes: float64(4), object(4)
# memory usage: 648.0+ bytes

# %%
#=====Working with revenue column

# %%
# Convert the object to integer type 
s=df["Revenue"]
s
# Out:
# 0    $11,757,018
# 1    $12,329,371
# 2    $10,597,009
# 3             NaN
# 4             NaN
# 5             NaN
# 6     $9,254,614
# 7     $9,451,943
# 8    $14,001,180
# Name: Revenue, dtype: object

# %%
# Fill 0 instead of nan 
df["Revenue"]=s=df["Revenue"].fillna("0")
df
# Out:
#     ID             Name            Industry  Inception       Revenue  \
# 0  1.0          Lamtone         IT Services     2009.0  $11,757,018
# 1  2.0        Stripfind  Financial Services     2010.0  $12,329,371
# 2  3.0  Canecorporation              Health     2012.0  $10,597,009
# 3  4.0              NaN         IT Services     2013.0             0
# 4  5.0              NaN                 NaN        NaN             0
# 5  6.0         Techline              Health     2006.0             0
# 6  7.0          Cityace                 NaN     2010.0   $9,254,614
# 7  8.0   Kayelectronics                 NaN     2009.0   $9,451,943
# 8  9.0          Ganzlax         IT Services     2011.0  $14,001,180
#
#             Expenses      Profit  Growth
# 0  6,482,465 Dollars   5274553.0    0.30
# 1    916,455 Dollars  11412916.0     NaN
# 2                NaN   3005820.0     NaN
# 3  7,429,377 Dollars   6597557.0     NaN
# 4  7,435,363 Dollars   3138627.0     NaN
# ...

# %%
p=df["Revenue"]
p
# Out:
# 0    $11,757,018
# 1    $12,329,371
# 2    $10,597,009
# 3               0
# 4               0
# 5               0
# 6     $9,254,614
# 7     $9,451,943
# 8    $14,001,180
# Name: Revenue, dtype: object

# %%
r=[]
for i in p:
    s=""
    for j in i:
        if (j.isdigit()):
            s=s+j
    r.append(s)
r
# Out:
# ['11757018',
#  '12329371',
#  '10597009',
#  '0',
#  '0',
#  '0',
#  '9254614',
#  '9451943',
#  '14001180']

# %%
df["Revenue"]=r
df
# Out:
#     ID             Name            Industry  Inception   Revenue  \
# 0  1.0          Lamtone         IT Services     2009.0  11757018
# 1  2.0        Stripfind  Financial Services     2010.0  12329371
# 2  3.0  Canecorporation              Health     2012.0  10597009
# 3  4.0              NaN         IT Services     2013.0         0
# 4  5.0              NaN                 NaN        NaN         0
# 5  6.0         Techline              Health     2006.0         0
# 6  7.0          Cityace                 NaN     2010.0   9254614
# 7  8.0   Kayelectronics                 NaN     2009.0   9451943
# 8  9.0          Ganzlax         IT Services     2011.0  14001180
#
#             Expenses      Profit  Growth
# 0  6,482,465 Dollars   5274553.0    0.30
# 1    916,455 Dollars  11412916.0     NaN
# 2                NaN   3005820.0     NaN
# 3  7,429,377 Dollars   6597557.0     NaN
# 4  7,435,363 Dollars   3138627.0     NaN
# 5  5,470,303 Dollars   8427816.0    0.23
# ...

# %%
df["Revenue"]=df["Revenue"].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 0 to 8
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         9 non-null      float64
#  1   Name       7 non-null      object
#  2   Industry   6 non-null      object
#  3   Inception  8 non-null      float64
#  4   Revenue    9 non-null      int64
#  5   Expenses   6 non-null      object
#  6   Profit     9 non-null      float64
#  7   Growth     5 non-null      float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 648.0+ bytes

# %%
#======== Working with Expenses columns

# %%
s=df["Expenses"]
s
# Out:
# 0    6,482,465 Dollars
# 1      916,455 Dollars
# 2                  NaN
# 3    7,429,377 Dollars
# 4    7,435,363 Dollars
# 5    5,470,303 Dollars
# 6                  NaN
# 7    3,878,113 Dollars
# 8                  NaN
# Name: Expenses, dtype: object

# %%
df["Expenses"]=df["Expenses"].fillna("0")
df
# Out:
#     ID             Name            Industry  Inception   Revenue  \
# 0  1.0          Lamtone         IT Services     2009.0  11757018
# 1  2.0        Stripfind  Financial Services     2010.0  12329371
# 2  3.0  Canecorporation              Health     2012.0  10597009
# 3  4.0              NaN         IT Services     2013.0         0
# 4  5.0              NaN                 NaN        NaN         0
# 5  6.0         Techline              Health     2006.0         0
# 6  7.0          Cityace                 NaN     2010.0   9254614
# 7  8.0   Kayelectronics                 NaN     2009.0   9451943
# 8  9.0          Ganzlax         IT Services     2011.0  14001180
#
#             Expenses      Profit  Growth
# 0  6,482,465 Dollars   5274553.0    0.30
# 1    916,455 Dollars  11412916.0     NaN
# 2                  0   3005820.0     NaN
# 3  7,429,377 Dollars   6597557.0     NaN
# 4  7,435,363 Dollars   3138627.0     NaN
# 5  5,470,303 Dollars   8427816.0    0.23
# ...

# %%
e=[]
for i in p:
    s=""
    for j in i:
        if (j.isdigit()):
            s=s+j
    e.append(s)
e
# Out:
# ['11757018',
#  '12329371',
#  '10597009',
#  '0',
#  '0',
#  '0',
#  '9254614',
#  '9451943',
#  '14001180']

# %%
df["Expenses"]=e
df
# Out:
#     ID             Name            Industry  Inception   Revenue  Expenses  \
# 0  1.0          Lamtone         IT Services     2009.0  11757018  11757018
# 1  2.0        Stripfind  Financial Services     2010.0  12329371  12329371
# 2  3.0  Canecorporation              Health     2012.0  10597009  10597009
# 3  4.0              NaN         IT Services     2013.0         0         0
# 4  5.0              NaN                 NaN        NaN         0         0
# 5  6.0         Techline              Health     2006.0         0         0
# 6  7.0          Cityace                 NaN     2010.0   9254614   9254614
# 7  8.0   Kayelectronics                 NaN     2009.0   9451943   9451943
# 8  9.0          Ganzlax         IT Services     2011.0  14001180  14001180
#
#        Profit  Growth
# 0   5274553.0    0.30
# 1  11412916.0     NaN
# 2   3005820.0     NaN
# 3   6597557.0     NaN
# 4   3138627.0     NaN
# 5   8427816.0    0.23
# 6   3005116.0    0.06
# 7   5573830.0    0.04
# ...

# %%
df["Expenses"]=df["Expenses"].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 0 to 8
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         9 non-null      float64
#  1   Name       7 non-null      object
#  2   Industry   6 non-null      object
#  3   Inception  8 non-null      float64
#  4   Revenue    9 non-null      int64
#  5   Expenses   9 non-null      int64
#  6   Profit     9 non-null      float64
#  7   Growth     5 non-null      float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 648.0+ bytes

# %%
# filling nan again instead of zero in Revenue column
df["Revenue"].replace(0,np.nan,inplace=True)
df
# Out:
#     ID             Name            Industry  Inception     Revenue  Expenses  \
# 0  1.0          Lamtone         IT Services     2009.0  11757018.0  11757018
# 1  2.0        Stripfind  Financial Services     2010.0  12329371.0  12329371
# 2  3.0  Canecorporation              Health     2012.0  10597009.0  10597009
# 3  4.0              NaN         IT Services     2013.0         NaN         0
# 4  5.0              NaN                 NaN        NaN         NaN         0
# 5  6.0         Techline              Health     2006.0         NaN         0
# 6  7.0          Cityace                 NaN     2010.0   9254614.0   9254614
# 7  8.0   Kayelectronics                 NaN     2009.0   9451943.0   9451943
# 8  9.0          Ganzlax         IT Services     2011.0  14001180.0  14001180
#
#        Profit  Growth
# 0   5274553.0    0.30
# 1  11412916.0     NaN
# 2   3005820.0     NaN
# 3   6597557.0     NaN
# 4   3138627.0     NaN
# 5   8427816.0    0.23
# 6   3005116.0    0.06
# ...

# %%
# filling nan again instead of zero in Expenses column
df["Expenses"].replace(0,np.nan,inplace=True)
df
# Out:
# C:\Users\brije\AppData\Local\Temp\ipykernel_23012\2214818100.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Expenses"].replace(0,np.nan,inplace=True)
#     ID             Name            Industry  Inception     Revenue  \
# 0  1.0          Lamtone         IT Services     2009.0  11757018.0
# 1  2.0        Stripfind  Financial Services     2010.0  12329371.0
# 2  3.0  Canecorporation              Health     2012.0  10597009.0
# 3  4.0              NaN         IT Services     2013.0         NaN
# ...

# %%
df[["Name","Industry"]]=df[["Name","Industry"]].fillna("Unknown")
df
# Out:
#     ID             Name            Industry  Inception     Revenue  \
# 0  1.0          Lamtone         IT Services     2009.0  11757018.0
# 1  2.0        Stripfind  Financial Services     2010.0  12329371.0
# 2  3.0  Canecorporation              Health     2012.0  10597009.0
# 3  4.0          Unknown         IT Services     2013.0         NaN
# 4  5.0          Unknown             Unknown        NaN         NaN
# 5  6.0         Techline              Health     2006.0         NaN
# 6  7.0          Cityace             Unknown     2010.0   9254614.0
# 7  8.0   Kayelectronics             Unknown     2009.0   9451943.0
# 8  9.0          Ganzlax         IT Services     2011.0  14001180.0
#
#      Expenses      Profit  Growth
# 0  11757018.0   5274553.0    0.30
# 1  12329371.0  11412916.0     NaN
# 2  10597009.0   3005820.0     NaN
# 3         NaN   6597557.0     NaN
# 4         NaN   3138627.0     NaN
# 5         NaN   8427816.0    0.23
# 6   9254614.0   3005116.0    0.06
# ...

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]
