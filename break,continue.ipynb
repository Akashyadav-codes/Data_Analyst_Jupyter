# %%
Break keyword: It is a keyword to terminate a Loop, according your condition

# %%
for i in range(0,20):
    if (i==5):
        time.Sleep(2)
        print("this is my first beak point",i)
        continue
    elif (i==10):
        time.Sleep(2)
        print("this is my second break point",i)
        continue
    elif (i==15):
        print("this is my third break point",i)
        break
    
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 for i in range(0,20):
#       2     if (i==5):
# ----> 3         time.Sleep(2)
#       4         print("this is my first beak point",i)
#       5         continue
#
# NameError: name 'time' is not defined

# %%
# USING PASS KEYWORD
x=20
y=10
z=x/y
print(z)
# Out:
# 2.0

# %%
Collection: Collection is the gruop of the data i.e. similar and different data type.


# two types: Similar and Different type
1.Similar: array
2. Diiferent: List , dict, tupple,set.
