# %%
import pandas as pd

# %%
data = {
    "Day": ["Mon","tues","Wed","Thur","Fri","Sat","Sun"],
    "Sales":[120,150,130,170,200,220,210]
    
}
df=pd.DataFrame(data)
df
# Out:
#     Day  Sales
# 0   Mon    120
# 1  tues    150
# 2   Wed    130
# 3  Thur    170
# 4   Fri    200
# 5   Sat    220
# 6   Sun    210

# %%
a=df["Sales"].mean()
a
# Out:
# np.float64(171.42857142857142)

# %%
df["Sales"].median()
# Out:
# 170.0

# %%
df["Sales"].mode()
# Out:
# 0    120
# 1    130
# 2    150
# 3    170
# 4    200
# 5    210
# 6    220
# Name: Sales, dtype: int64

# %%
df["Sales"].var()
# Out:
# 1580.952380952381

# %%
df["Sales"].std()
# Out:
# 39.7611918955202

# %%
df[df["Sales"]==df["Sales"].max()]
# Out:
#    Day  Sales
# 5  Sat    220

# %%
df[df["Sales"]==df["Sales"].min()]
# Out:
#    Day  Sales
# 0  Mon    120

# %%
df[df["Sales"]>a]
# Out:
#    Day  Sales
# 4  Fri    200
# 5  Sat    220
# 6  Sun    210

# %%
df[df["Sales"]<a]
# Out:
#     Day  Sales
# 0   Mon    120
# 1  tues    150
# 2   Wed    130
# 3  Thur    170

# %%
import matplotlib.pyplot as plt
plt.hist(df["Sales"],bins=5)
plt.show()
